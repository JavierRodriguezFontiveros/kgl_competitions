# %% [markdown]
# ## Datos
#
# 1. Company- String -Laptop Manufacturer
#
# 2. Product -String -Brand and Model
#
# 3. TypeName -String -Type (Notebook, Ultrabook, Gaming, etc.)
#
# 4. Inches -Numeric- Screen Size
#
# 5. ScreenResolution -String- Screen Resolution
#
# 6. Cpu- String -Central Processing Unit (CPU)
#
# 7. Ram -String- Laptop RAM
#
# 8. Memory -String- Hard Disk / SSD Memory
#
# 9. GPU -String- Graphics Processing Units (GPU)
#
# 10. OpSys -String- Operating System
#
# 11. Weight -String- Laptop Weight
#
# 12. Price_euros -Numeric- Price (Euro)

# %% [markdown]
# # Bibliotecas

# %%
import Modelos as mod

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

import re

# %% [markdown]
# ## Limpieza de datos

# %%
#Modelo lineal 1.

#Limpiar Dataframe Train
df = pd.read_csv("train.csv", index_col = "id")
print(df.shape)
df.sort_values(by = "laptop_ID", inplace = True)

#1.PESO:
df['Weight'] = df['Weight'].str.replace('kg', '').astype(float)

#2.RAM:
df['Ram'] = df['Ram'].str.replace('GB', '').astype(float)

#3.MEMORY:
def extract_storage_capacity(mem_str):
    gb_match = re.search(r'(\d+)GB', mem_str)
    tb_match = re.search(r'(\d+)TB', mem_str)
    gb_value = int(gb_match.group(1)) if gb_match else 0
    tb_value = int(tb_match.group(1)) * 1024 if tb_match else 0
    return gb_value + tb_value

def extract_storage_type(mem_str):
    if 'SSD' in mem_str:
        return 'SSD'
    elif 'HDD' in mem_str:
        return 'HDD'
    elif 'Hybrid' in mem_str:
        return 'Hybrid'
    elif 'Flash Storage' in mem_str:
        return 'Flash Storage'
    return 'Unknown'

df['Storage_Capacity'] = df['Memory'].apply(extract_storage_capacity)
df['Storage_Type'] = df['Memory'].apply(extract_storage_type)
# Out:
# (912, 13)

# %%
#Modelo Lineal:
X = df[["Weight","Ram"]]
Y = df["Price_euros"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=40)

model = LinearRegression()
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)
mae = mean_absolute_error(Y_test, Y_pred)
    
print("MAE en conjunto de validación:", mae)


#Limpiar Dataframe Test:

df_test = pd.read_csv("test.csv", index_col = 0)
df_test.sort_index(inplace = True)
df_test['Weight'] = df_test['Weight'].str.replace('kg', '').astype(float)
df_test['Ram'] = df_test['Ram'].str.replace('GB', '').astype(float)
x_test = df_test[["Weight","Ram"]]


#Aplicar el modelo:
y_pred_test = model.predict(x_test)
resultados = pd.DataFrame({'id':df_test.index,
                           "Price_euros":y_pred_test})

#Imprimir el CSV:
resultados.to_csv("Resultados/Prueba_3_linear.csv", index= False)
# Out:
# MAE en conjunto de validación: 347.1643380815848

# %%
#Modelo lineal 1.

#Limpiar Dataframe Train
df = pd.read_csv("train.csv", index_col = "id")

df.sort_values(by = "laptop_ID", inplace = True)

df['Weight'] = df['Weight'].str.replace('kg', '').astype(float)
df['Ram'] = df['Ram'].str.replace('GB', '').astype(float)

#Modelo Lineal:
X = df[["Weight","Ram"]]
Y = df["Price_euros"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=40)

model = LinearRegression()
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)
mae = mean_absolute_error(Y_test, Y_pred)
    
print("MAE en conjunto de validación:", mae)


#Limpiar Dataframe Test:

df_test = pd.read_csv("test.csv", index_col = 0)
df_test.sort_index(inplace = True)
df_test['Weight'] = df_test['Weight'].str.replace('kg', '').astype(float)
df_test['Ram'] = df_test['Ram'].str.replace('GB', '').astype(float)
x_test = df_test[["Weight","Ram"]]


#Aplicar el modelo:
y_pred_test = model.predict(x_test)
resultados = pd.DataFrame({'id':df_test.index,
                           "Price_euros":y_pred_test})

#Imprimir el CSV:
resultados.to_csv("Resultados/Prueba_1_linear.csv", index= False)
# Out:
# MAE en conjunto de validación: 347.1643380815848

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# id
# 427           1   Apple                          MacBook Pro
# 23            2   Apple                          Macbook Air
# 1067          3      HP                               250 G6
# 74            4   Apple                          MacBook Pro
# 323           5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1179       1313    Dell                        Inspiron 3567
# 511        1314      HP                     Stream 11-Y000na
# 1193       1316  Lenovo                       Yoga 500-14ISK
# 1169       1317  Lenovo                       Yoga 900-13ISK
# 1083       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# id
# 427            Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 23             Ultrabook    13.3                                    1440x900
# 1067            Notebook    15.6                           Full HD 1920x1080
# 74             Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 323            Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1179            Notebook    15.6                                    1366x768
# 511              Netbook    11.6                                    1366x768
# 1193  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1169  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1083            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# id
# 427                   Intel Core i5 2.3GHz   8.0            128GB SSD
# 23                    Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 1067            Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 74                    Intel Core i7 2.7GHz  16.0            512GB SSD
# 323                   Intel Core i5 3.1GHz   8.0            256GB SSD
# ...                                    ...   ...                  ...
# 1179            Intel Core i7 7500U 2.7GHz   8.0              1TB HDD
# 511   Intel Celeron Dual Core N3060 1.6GHz   2.0   32GB Flash Storage
# 1193            Intel Core i7 6500U 2.5GHz   4.0            128GB SSD
# 1169            Intel Core i7 6500U 2.5GHz  16.0            512GB SSD
# 1083  Intel Celeron Dual Core N3050 1.6GHz   4.0            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# id
# 427   Intel Iris Plus Graphics 640       macOS    1.37      1339.69
# 23          Intel HD Graphics 6000       macOS    1.34       898.94
# 1067         Intel HD Graphics 620       No OS    1.86       575.00
# 74              AMD Radeon Pro 455       macOS    1.83      2537.45
# 323   Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# ...                            ...         ...     ...          ...
# 1179            AMD Radeon R5 M430       Linux    2.30       805.99
# 511          Intel HD Graphics 400  Windows 10    1.17       209.00
# 1193         Intel HD Graphics 520  Windows 10    1.80       638.00
# 1169         Intel HD Graphics 520  Windows 10    1.30      1499.00
# 1083             Intel HD Graphics  Windows 10    2.20       369.00
#
# [912 rows x 13 columns]

# %% [markdown]
# # Limpieza de datos y groupby

# %%
df = pd.read_csv("train.csv", index_col = "id")
df.sort_values(by = "laptop_ID", inplace = True)
df['Weight'] = df['Weight'].str.replace('kg', '').astype(float)
df['Ram'] = df['Ram'].str.replace('GB', '').astype(float)

medianas_type = df.groupby('Memory')['Price_euros'].median().reset_index()
medianas_type.rename(columns={'Price_euros': 'Med_Memory'}, inplace=True)

df = df.merge(medianas_type, on='Memory', how='left')

# %%
df = pd.read_csv("train.csv", index_col = "id")
df.sort_values(by = "laptop_ID", inplace = True)
df['Weight'] = df['Weight'].str.replace('kg', '').astype(float)
df['Ram'] = df['Ram'].str.replace('GB', '').astype(float)

medianas = df.groupby('Company')['Price_euros'].median().reset_index()
medianas.rename(columns={'Price_euros': 'Marca_mediana'}, inplace=True)

# Merge con el DataFrame original para agregar la nueva columna
df = df.merge(medianas, on='Company', how='left')

# Mostrar el DataFrame resultante
df
# Out:
#      laptop_ID Company                              Product  \
# 0            1   Apple                          MacBook Pro
# 1            2   Apple                          Macbook Air
# 2            3      HP                               250 G6
# 3            4   Apple                          MacBook Pro
# 4            5   Apple                          MacBook Pro
# ..         ...     ...                                  ...
# 907       1313    Dell                        Inspiron 3567
# 908       1314      HP                     Stream 11-Y000na
# 909       1316  Lenovo                       Yoga 500-14ISK
# 910       1317  Lenovo                       Yoga 900-13ISK
# 911       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                TypeName  Inches                            ScreenResolution  \
# 0             Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1             Ultrabook    13.3                                    1440x900
# 2              Notebook    15.6                           Full HD 1920x1080
# 3             Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4             Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ..                  ...     ...                                         ...
# 907            Notebook    15.6                                    1366x768
# 908             Netbook    11.6                                    1366x768
# 909  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 910  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 911            Notebook    15.6                                    1366x768
#
#                                       Cpu   Ram               Memory  \
# 0                    Intel Core i5 2.3GHz   8.0            128GB SSD
# 1                    Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2              Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3                    Intel Core i7 2.7GHz  16.0            512GB SSD
# 4                    Intel Core i5 3.1GHz   8.0            256GB SSD
# ..                                    ...   ...                  ...
# 907            Intel Core i7 7500U 2.7GHz   8.0              1TB HDD
# 908  Intel Celeron Dual Core N3060 1.6GHz   2.0   32GB Flash Storage
# 909            Intel Core i7 6500U 2.5GHz   4.0            128GB SSD
# 910            Intel Core i7 6500U 2.5GHz  16.0            512GB SSD
# 911  Intel Celeron Dual Core N3050 1.6GHz   4.0            500GB HDD
#
#                               Gpu       OpSys  Weight  Price_euros  \
# 0    Intel Iris Plus Graphics 640       macOS    1.37      1339.69
# 1          Intel HD Graphics 6000       macOS    1.34       898.94
# 2           Intel HD Graphics 620       No OS    1.86       575.00
# 3              AMD Radeon Pro 455       macOS    1.83      2537.45
# 4    Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# ..                            ...         ...     ...          ...
# 907            AMD Radeon R5 M430       Linux    2.30       805.99
# 908         Intel HD Graphics 400  Windows 10    1.17       209.00
# 909         Intel HD Graphics 520  Windows 10    1.80       638.00
# 910         Intel HD Graphics 520  Windows 10    1.30      1499.00
# 911             Intel HD Graphics  Windows 10    2.20       369.00
#
#      Marca_mediana
# 0          1339.69
# 1          1339.69
# 2           914.00
# 3          1339.69
# 4          1339.69
# ..             ...
# 907         949.00
# 908         914.00
# 909         899.00
# 910         899.00
# 911         963.00
#
# [912 rows x 14 columns]

# %%
medianas_type = df.groupby('TypeName')['Price_euros'].median().reset_index()
medianas_type.rename(columns={'Price_euros': 'Mediana_Precio_Type'}, inplace=True)

# Merge con el DataFrame original para agregar la nueva columna
df = df.merge(medianas_type, on='TypeName', how='left')
df
# Out:
#      laptop_ID Company                              Product  \
# 0            1   Apple                          MacBook Pro
# 1            2   Apple                          Macbook Air
# 2            3      HP                               250 G6
# 3            4   Apple                          MacBook Pro
# 4            5   Apple                          MacBook Pro
# ..         ...     ...                                  ...
# 907       1313    Dell                        Inspiron 3567
# 908       1314      HP                     Stream 11-Y000na
# 909       1316  Lenovo                       Yoga 500-14ISK
# 910       1317  Lenovo                       Yoga 900-13ISK
# 911       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                TypeName  Inches                            ScreenResolution  \
# 0             Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1             Ultrabook    13.3                                    1440x900
# 2              Notebook    15.6                           Full HD 1920x1080
# 3             Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4             Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ..                  ...     ...                                         ...
# 907            Notebook    15.6                                    1366x768
# 908             Netbook    11.6                                    1366x768
# 909  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 910  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 911            Notebook    15.6                                    1366x768
#
#                                       Cpu   Ram               Memory  \
# 0                    Intel Core i5 2.3GHz   8.0            128GB SSD
# 1                    Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2              Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3                    Intel Core i7 2.7GHz  16.0            512GB SSD
# 4                    Intel Core i5 3.1GHz   8.0            256GB SSD
# ..                                    ...   ...                  ...
# 907            Intel Core i7 7500U 2.7GHz   8.0              1TB HDD
# 908  Intel Celeron Dual Core N3060 1.6GHz   2.0   32GB Flash Storage
# 909            Intel Core i7 6500U 2.5GHz   4.0            128GB SSD
# 910            Intel Core i7 6500U 2.5GHz  16.0            512GB SSD
# 911  Intel Celeron Dual Core N3050 1.6GHz   4.0            500GB HDD
#
#                               Gpu       OpSys  Weight  Price_euros  \
# 0    Intel Iris Plus Graphics 640       macOS    1.37      1339.69
# 1          Intel HD Graphics 6000       macOS    1.34       898.94
# 2           Intel HD Graphics 620       No OS    1.86       575.00
# 3              AMD Radeon Pro 455       macOS    1.83      2537.45
# 4    Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# ..                            ...         ...     ...          ...
# 907            AMD Radeon R5 M430       Linux    2.30       805.99
# 908         Intel HD Graphics 400  Windows 10    1.17       209.00
# 909         Intel HD Graphics 520  Windows 10    1.80       638.00
# 910         Intel HD Graphics 520  Windows 10    1.30      1499.00
# 911             Intel HD Graphics  Windows 10    2.20       369.00
#
#      Marca_mediana  Mediana_Precio_Type
# 0          1339.69               1495.0
# 1          1339.69               1495.0
# 2           914.00                689.0
# 3          1339.69               1495.0
# 4          1339.69               1495.0
# ..             ...                  ...
# 907         949.00                689.0
# 908         914.00                269.0
# 909         899.00               1159.0
# 910         899.00               1159.0
# 911         963.00                689.0
#
# [912 rows x 15 columns]

# %%
precio_promedio_tipo = df.groupby('TypeName')['Price_euros'].mean().sort_values(ascending=False)
print(precio_promedio_tipo)
# Out:
# TypeName
# Workstation           2494.864444
# Gaming                1764.080217
# Ultrabook             1530.688148
# 2 in 1 Convertible    1248.470471
# Notebook               768.970575
# Netbook                577.992857
# Name: Price_euros, dtype: float64

# %%
precio_promedio_empresa = df.groupby('Company')['Price_euros'].mean().sort_values(ascending=False)
print(precio_promedio_empresa)
# Out:
# Company
# Razer        3420.666667
# LG           2299.000000
# Google       1879.000000
# MSI          1763.828824
# Apple        1557.304118
# Samsung      1427.333333
# Microsoft    1398.950000
# Huawei       1349.000000
# Toshiba      1236.594595
# Dell         1175.476570
# Lenovo       1099.752548
# Xiaomi       1044.633333
# HP           1042.357884
# Asus         1034.531852
# Fujitsu       729.000000
# Acer          644.774800
# Mediacom      295.000000
# Chuwi         246.945000
# Vero          224.566667
# Name: Price_euros, dtype: float64

# %%
#Modelo 2 polinomico:

# Cargar y preparar los datos
df = pd.read_csv("train.csv", index_col="id")
df.sort_values(by="laptop_ID", inplace=True)
df['Weight'] = df['Weight'].str.replace('kg', '').astype(float)
df['Ram'] = df['Ram'].str.replace('GB', '').astype(float)


X = df[["Weight", "Ram"]]
Y = df["Price_euros"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=40)

poly = PolynomialFeatures(degree=2)

X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

model = LinearRegression()
model.fit(X_train_poly, Y_train)

Y_pred = model.predict(X_test_poly)

mae_3 = mean_absolute_error(Y_test, Y_pred)

print("MAE:", mae_3)

# Cargar el conjunto de prueba
df_test = pd.read_csv("test.csv", index_col=0)
df_test.sort_index(inplace=True)

df_test['Weight'] = df_test['Weight'].str.replace('kg', '').astype(float)
df_test['Ram'] = df_test['Ram'].str.replace('GB', '').astype(float)

# Preparar el conjunto de prueba
x_test = df_test[["Weight", "Ram"]]
X_test_poly = poly.transform(x_test)  # Corregido aquí

y_pred_test = model.predict(X_test_poly)  # Usando el conjunto de prueba transformado correctamente

# Crear el DataFrame de resultados
resultados = pd.DataFrame({'id': df_test.index,
                           "Price_euros": y_pred_test})

resultados.to_csv("Resultados/Prueba_2_polinomica.csv", index=False)
# Out:
# MAE: 332.7311472207639

# %%
#Modelo 3 polinomico:

# Cargar y preparar los datos
df = pd.read_csv("train.csv", index_col="id")
df.sort_values(by="laptop_ID", inplace=True)
df['Weight'] = df['Weight'].str.replace('kg', '').astype(float)
df['Ram'] = df['Ram'].str.replace('GB', '').astype(float)

medianas_type = df.groupby('Memory')['Price_euros'].median().reset_index()
medianas_type.rename(columns={'Price_euros': 'Med_Memory'}, inplace=True)

df = df.merge(medianas_type, on='Memory', how='left')


X = df[["Weight", "Ram", "Med_Memory"]]
Y = df["Price_euros"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=40)

poly = PolynomialFeatures(degree=2)

X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

model = LinearRegression()
model.fit(X_train_poly, Y_train)

Y_pred = model.predict(X_test_poly)

mae_3 = mean_absolute_error(Y_test, Y_pred)

print("MAE:", mae_3)
# Out:
# MAE: 291.12038449596434

# %%
#Insertar la nueva columna creada copiarla en e test
#que si no se generan missingvalues

# %%
# Cargar el conjunto de prueba
df_test = pd.read_csv("test.csv", index_col=0)
df_test.sort_index(inplace=True)

df_test['Weight'] = df_test['Weight'].str.replace('kg', '').astype(float)
df_test['Ram'] = df_test['Ram'].str.replace('GB', '').astype(float)




# Preparar el conjunto de prueba
x_test = df_test[["Weight", "Ram", "Med_Memory"]]
X_test_poly = poly.transform(x_test)  # Corregido aquí

y_pred_test = model.predict(X_test_poly)  # Usando el conjunto de prueba transformado correctamente

# Crear el DataFrame de resultados
resultados = pd.DataFrame({'id': df_test.index,
                           "Price_euros": y_pred_test})

resultados.to_csv("Resultados/Prueba_3_polinomica.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 12
#       6 df_test['Ram'] = df_test['Ram'].str.replace('GB', '').astype(float)
#      11 # Preparar el conjunto de prueba
# ---> 12 x_test = df_test[["Weight", "Ram", "Med_Memory"]]
#      13 X_test_poly = poly.transform(x_test)  # Corregido aquí
#      15 y_pred_test = model.predict(X_test_poly)  # Usando el conjunto de prueba transformado correctamente
#
# File c:\Users\Jjaavviieerroperro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Jjaavviieerroperro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Jjaavviieerroperro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Med_Memory'] not in index"
